# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Load the data you receive into a Pandas DataFrame

# %%
df = pd.read_csv('pyramid_scheme.csv')

# %% [markdown]
# ### Show the first five rows of the data set

# %%
df.head(5)
# Out:
#    Unnamed: 0  cost_price  profit_markup  depth_of_tree  sales_commission  \
# 0           1        3500              2             21              1000
# 1           2        3500              2             26              1000
# 2           3        3500              2             23              1000
# 3           4        3500              3             12              1000
# 4           5        3500              2             12              1000
#
#    profit
# 0  -16500
# 1  -21500
# 2  -18500
# 3   -4000
# 4   -7500

# %% [markdown]
# ### Show the description and the info of the data set

# %%
df.describe()
# Out:
#        Unnamed: 0  cost_price  profit_markup  depth_of_tree  sales_commission  \
# count  500.000000       500.0     500.000000     500.000000             500.0
# mean   250.500000      3500.0       3.498000      15.896000            1000.0
# std    144.481833         0.0       1.126292       8.095694               0.0
# min      1.000000      3500.0       2.000000       2.000000            1000.0
# 25%    125.750000      3500.0       3.000000       9.000000            1000.0
# 50%    250.500000      3500.0       3.000000      16.000000            1000.0
# 75%    375.250000      3500.0       5.000000      23.000000            1000.0
# max    500.000000      3500.0       5.000000      30.000000            1000.0
#
#              profit
# count    500.000000
# mean   -6153.000000
# std     9080.528784
# min   -25500.000000
# 25%   -12500.000000
# 50%    -6500.000000
# 75%      500.000000
# max    13000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
# Unnamed: 0          500 non-null int64
# cost_price          500 non-null int64
# profit_markup       500 non-null int64
# depth_of_tree       500 non-null int64
# sales_commission    500 non-null int64
# profit              500 non-null int64
# dtypes: int64(6)
# memory usage: 23.6 KB

# %% [markdown]
# ### Using a regression model, split your data into train and test data

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.plot(x='depth_of_tree', y='profit',style='.' )
plt.title('Do pyramid schemes make you money?')
plt.xlabel('People above you on tree')
plt.ylabel('Profit')



plt.show()

# %%
df.plot(x='depth_of_tree', y='profit')
plt.title('Do pyramid schemes make you money?')
plt.xlabel('People above you on tree')
plt.ylabel('Profit')

plt.show()

# %% [markdown]
# Conclusion one: You can only really make money from a pyramid scheme if you are one of the first three on the downline.
# Conclusion two: People are willing to lose a lot of money in pyramid schemes.
# Conclusion three: If you can succesfully start a pyramid scheme there is a lot of money to be made
